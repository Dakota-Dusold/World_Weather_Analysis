# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Import the requests library.
import requests
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})

        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | batagay-alyta
# Processing Record 3 of Set 1 | ahipara
# Processing Record 4 of Set 1 | marsh harbour
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | prince rupert
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | cayenne
# Processing Record 9 of Set 1 | lasa
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | hay river
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | gravdal
# Processing Record 18 of Set 1 | nanortalik
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | durango
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | bonthe
# Processing Record 24 of Set 1 | fare
# Processing Record 25 of Set 1 | longyearbyen
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | bambous virieux
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | craig
# Processing Record 30 of Set 1 | maitum
# Processing Record 31 of Set 1 | bilma
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | vadinsk
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | sao gabriel da cachoeira
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | de aar
# Processing Record 45 of Set 1 | caravelas
# Processing Record 46 of Set 1 | jiuquan
# Processing Record 47 of Set 1 | richards bay
# Processing Record 48 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 1 | venice
# Processing Record 50 of Set 1 | tuatapere
# Processing Record 1 of Set 2 | sioux lookout
# Processing Record 2 of Set 2 | halifax
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | murmashi
# Processing Record 5 of Set 2 | agustin codazzi
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | kargil
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | hofn
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | los llanos de aridane
# Processing Record 13 of Set 2 | axim
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | kaeo
# Processing Record 16 of Set 2 | trat
# Processing Record 17 of Set 2 | henties bay
# Processing Record 18 of Set 2 | kazachinskoye
# Processing Record 19 of Set 2 | barra do garcas
# Processing Record 20 of Set 2 | saint-francois
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | margate
# Processing Record 23 of Set 2 | port hardy
# Processing Record 24 of Set 2 | eyl
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | karlskrona
# Processing Record 27 of Set 2 | bafra
# Processing Record 28 of Set 2 | bandarbeyla
# Processing Record 29 of Set 2 | santiago del estero
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | mehamn
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | ngunguru
# Processing Record 34 of Set 2 | masakin
# Processing Record 35 of Set 2 | hami
# Processing Record 36 of Set 2 | ponta do sol
# Processing Record 37 of Set 2 | krasnoselkup
# Processing Record 38 of Set 2 | foster city
# Processing Record 39 of Set 2 | arrecife
# Processing Record 40 of Set 2 | las juntas
# Processing Record 41 of Set 2 | tungkang
# City not found. Skipping...
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | nogliki
# Processing Record 44 of Set 2 | lompoc
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | aleksandrov gay
# Processing Record 47 of Set 2 | qaqortoq
# Processing Record 48 of Set 2 | linjiang
# Processing Record 49 of Set 2 | mutare
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | ranong
# Processing Record 2 of Set 3 | ladario
# Processing Record 3 of Set 3 | labuhan
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | semey
# Processing Record 6 of Set 3 | salinopolis
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | port-cartier
# Processing Record 9 of Set 3 | middelburg
# Processing Record 10 of Set 3 | shush
# Processing Record 11 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 3 | at-bashi
# Processing Record 13 of Set 3 | horsham
# Processing Record 14 of Set 3 | manado
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | waipawa
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | acarau
# Processing Record 19 of Set 3 | mandi bahauddin
# Processing Record 20 of Set 3 | ciudad bolivar
# Processing Record 21 of Set 3 | esperance
# Processing Record 22 of Set 3 | port moresby
# Processing Record 23 of Set 3 | hovd
# Processing Record 24 of Set 3 | havre-saint-pierre
# Processing Record 25 of Set 3 | popondetta
# Processing Record 26 of Set 3 | oranjestad
# Processing Record 27 of Set 3 | olga
# Processing Record 28 of Set 3 | jumla
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | rabo de peixe
# Processing Record 31 of Set 3 | khatanga
# Processing Record 32 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 3 | illapel
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | hambantota
# Processing Record 36 of Set 3 | chernyshevskiy
# Processing Record 37 of Set 3 | luoyang
# Processing Record 38 of Set 3 | tena
# Processing Record 39 of Set 3 | mednogorskiy
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | san cristobal
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | katsuura
# Processing Record 46 of Set 3 | laguna
# Processing Record 47 of Set 3 | constitucion
# Processing Record 48 of Set 3 | pangnirtung
# Processing Record 49 of Set 3 | nikolskoye
# Processing Record 50 of Set 3 | tateyama
# Processing Record 1 of Set 4 | xuanhua
# Processing Record 2 of Set 4 | jamestown
# Processing Record 3 of Set 4 | fuerte olimpo
# Processing Record 4 of Set 4 | tukrah
# Processing Record 5 of Set 4 | kapaa
# Processing Record 6 of Set 4 | leningradskiy
# Processing Record 7 of Set 4 | taoudenni
# Processing Record 8 of Set 4 | dikson
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | ndende
# Processing Record 11 of Set 4 | barinas
# Processing Record 12 of Set 4 | zhelyabovka
# Processing Record 13 of Set 4 | manokwari
# Processing Record 14 of Set 4 | fortuna
# Processing Record 15 of Set 4 | mahebourg
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | mugur-aksy
# Processing Record 18 of Set 4 | morro bay
# Processing Record 19 of Set 4 | blythe
# Processing Record 20 of Set 4 | zhigansk
# Processing Record 21 of Set 4 | alta floresta
# Processing Record 22 of Set 4 | seinajoki
# Processing Record 23 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 4 | moose factory
# Processing Record 25 of Set 4 | half moon bay
# Processing Record 26 of Set 4 | kibala
# Processing Record 27 of Set 4 | ostersund
# Processing Record 28 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 4 | deputatskiy
# Processing Record 30 of Set 4 | aksha
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | iskateley
# Processing Record 33 of Set 4 | torbay
# Processing Record 34 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 4 | kaifeng
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | tayibe
# City not found. Skipping...
# Processing Record 39 of Set 4 | san patricio
# Processing Record 40 of Set 4 | grindavik
# Processing Record 41 of Set 4 | sao joao da barra
# Processing Record 42 of Set 4 | astoria
# Processing Record 43 of Set 4 | conakry
# Processing Record 44 of Set 4 | tongzi
# Processing Record 45 of Set 4 | senador jose porfirio
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | pangkalanbuun
# Processing Record 48 of Set 4 | norman wells
# Processing Record 49 of Set 4 | new norfolk
# Processing Record 50 of Set 4 | skorodnoye
# Processing Record 1 of Set 5 | bulach
# Processing Record 2 of Set 5 | utkivka
# Processing Record 3 of Set 5 | araouane
# Processing Record 4 of Set 5 | sola
# Processing Record 5 of Set 5 | roald
# Processing Record 6 of Set 5 | gubkinskiy
# Processing Record 7 of Set 5 | bethel
# Processing Record 8 of Set 5 | oktyabrskiy
# Processing Record 9 of Set 5 | kade
# Processing Record 10 of Set 5 | mount gambier
# Processing Record 11 of Set 5 | carballo
# Processing Record 12 of Set 5 | mumbwa
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 5 | yellowknife
# Processing Record 16 of Set 5 | solnechnyy
# Processing Record 17 of Set 5 | chuy
# Processing Record 18 of Set 5 | leh
# Processing Record 19 of Set 5 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 20 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 5 | paragominas
# Processing Record 22 of Set 5 | salta
# Processing Record 23 of Set 5 | davila
# Processing Record 24 of Set 5 | kroonstad
# Processing Record 25 of Set 5 | banjar
# Processing Record 26 of Set 5 | sterling
# Processing Record 27 of Set 5 | virginia beach
# Processing Record 28 of Set 5 | lumeje
# Processing Record 29 of Set 5 | nioro
# Processing Record 30 of Set 5 | miyang
# Processing Record 31 of Set 5 | giyani
# Processing Record 32 of Set 5 | korla
# Processing Record 33 of Set 5 | nome
# Processing Record 34 of Set 5 | olinda
# Processing Record 35 of Set 5 | buin
# Processing Record 36 of Set 5 | asfi
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 39 of Set 5 | touros
# Processing Record 40 of Set 5 | comodoro rivadavia
# Processing Record 41 of Set 5 | novyy urengoy
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | kloulklubed
# Processing Record 44 of Set 5 | lewisville
# Processing Record 45 of Set 5 | barcelona
# Processing Record 46 of Set 5 | fort myers beach
# Processing Record 47 of Set 5 | cockburn town
# Processing Record 48 of Set 5 | komsomolskiy
# Processing Record 49 of Set 5 | flinders
# Processing Record 50 of Set 5 | vestmannaeyjar
# Processing Record 1 of Set 6 | clyde river
# Processing Record 2 of Set 6 | itarema
# Processing Record 3 of Set 6 | saint anthony
# Processing Record 4 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 7 of Set 6 | waingapu
# Processing Record 8 of Set 6 | santa rosa
# Processing Record 9 of Set 6 | tefe
# Processing Record 10 of Set 6 | dunda
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | san
# Processing Record 13 of Set 6 | rio grande
# Processing Record 14 of Set 6 | tabuk
# Processing Record 15 of Set 6 | quatre cocos
# Processing Record 16 of Set 6 | yulara
# Processing Record 17 of Set 6 | hatillo
# Processing Record 18 of Set 6 | porteirinha
# Processing Record 19 of Set 6 | colares
# Processing Record 20 of Set 6 | finschhafen
# Processing Record 21 of Set 6 | chopda
# Processing Record 22 of Set 6 | bathsheba
# Processing Record 23 of Set 6 | evensk
# Processing Record 24 of Set 6 | bikin
# Processing Record 25 of Set 6 | kedrovyy
# Processing Record 26 of Set 6 | serik
# Processing Record 27 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 6 | seoul
# Processing Record 29 of Set 6 | sorong
# Processing Record 30 of Set 6 | kamina
# Processing Record 31 of Set 6 | kyren
# Processing Record 32 of Set 6 | meulaboh
# Processing Record 33 of Set 6 | teghra
# Processing Record 34 of Set 6 | kulhudhuffushi
# Processing Record 35 of Set 6 | suamico
# Processing Record 36 of Set 6 | bengesti
# Processing Record 37 of Set 6 | pimentel
# Processing Record 38 of Set 6 | salalah
# Processing Record 39 of Set 6 | lavrentiya
# Processing Record 40 of Set 6 | isangel
# Processing Record 41 of Set 6 | svarstad
# Processing Record 42 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 6 | biak
# Processing Record 44 of Set 6 | biloela
# Processing Record 45 of Set 6 | lalsk
# Processing Record 46 of Set 6 | vila
# Processing Record 47 of Set 6 | moron
# Processing Record 48 of Set 6 | general roca
# Processing Record 49 of Set 6 | coquimbo
# Processing Record 50 of Set 6 | guerrero negro
# Processing Record 1 of Set 7 | souillac
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | pingliang
# Processing Record 4 of Set 7 | san jose de rio tinto
# Processing Record 5 of Set 7 | tessalit
# Processing Record 6 of Set 7 | ketchikan
# Processing Record 7 of Set 7 | nalut
# Processing Record 8 of Set 7 | saldanha
# Processing Record 9 of Set 7 | canutama
# Processing Record 10 of Set 7 | santo angelo
# Processing Record 11 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 7 | pacific grove
# Processing Record 13 of Set 7 | kavaratti
# Processing Record 14 of Set 7 | kutum
# Processing Record 15 of Set 7 | havoysund
# Processing Record 16 of Set 7 | carnarvon
# Processing Record 17 of Set 7 | boyolangu
# Processing Record 18 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 7 | te anau
# Processing Record 21 of Set 7 | tezu
# Processing Record 22 of Set 7 | la ronge
# Processing Record 23 of Set 7 | taiyuan
# Processing Record 24 of Set 7 | broken hill
# Processing Record 25 of Set 7 | hasaki
# Processing Record 26 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 7 | buraydah
# Processing Record 28 of Set 7 | fairbanks
# Processing Record 29 of Set 7 | panama city
# Processing Record 30 of Set 7 | montpelier
# Processing Record 31 of Set 7 | omboue
# Processing Record 32 of Set 7 | teya
# Processing Record 33 of Set 7 | kavieng
# Processing Record 34 of Set 7 | acuna
# City not found. Skipping...
# Processing Record 35 of Set 7 | saint-joseph
# Processing Record 36 of Set 7 | chumikan
# Processing Record 37 of Set 7 | hervey bay
# Processing Record 38 of Set 7 | astara
# Processing Record 39 of Set 7 | provideniya
# Processing Record 40 of Set 7 | yarada
# Processing Record 41 of Set 7 | blackwater
# Processing Record 42 of Set 7 | pisco
# Processing Record 43 of Set 7 | talnakh
# Processing Record 44 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 7 | victoria
# Processing Record 46 of Set 7 | saint-philippe
# Processing Record 47 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 48 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 7 | taksimo
# Processing Record 50 of Set 7 | sao filipe
# Processing Record 1 of Set 8 | kieta
# Processing Record 2 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 8 | sao felix do xingu
# Processing Record 4 of Set 8 | mana
# Processing Record 5 of Set 8 | les cayes
# Processing Record 6 of Set 8 | ballina
# Processing Record 7 of Set 8 | arraial do cabo
# Processing Record 8 of Set 8 | port macquarie
# Processing Record 9 of Set 8 | ayan
# Processing Record 10 of Set 8 | koster
# Processing Record 11 of Set 8 | phun phin
# City not found. Skipping...
# Processing Record 12 of Set 8 | peace river
# Processing Record 13 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 8 | kolokani
# Processing Record 16 of Set 8 | aksarka
# Processing Record 17 of Set 8 | amvrosiyivka
# Processing Record 18 of Set 8 | launceston
# Processing Record 19 of Set 8 | impfondo
# Processing Record 20 of Set 8 | campbell river
# Processing Record 21 of Set 8 | kitimat
# Processing Record 22 of Set 8 | grand gaube
# Processing Record 23 of Set 8 | thinadhoo
# Processing Record 24 of Set 8 | oreanda
# City not found. Skipping...
# Processing Record 25 of Set 8 | codrington
# Processing Record 26 of Set 8 | cidreira
# Processing Record 27 of Set 8 | syracuse
# Processing Record 28 of Set 8 | ojinaga
# Processing Record 29 of Set 8 | shu
# Processing Record 30 of Set 8 | chapais
# Processing Record 31 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 8 | iberia
# Processing Record 33 of Set 8 | la asuncion
# Processing Record 34 of Set 8 | almaznyy
# Processing Record 35 of Set 8 | bengkulu
# Processing Record 36 of Set 8 | yazman
# Processing Record 37 of Set 8 | shenjiamen
# Processing Record 38 of Set 8 | kisangani
# Processing Record 39 of Set 8 | iralaya
# Processing Record 40 of Set 8 | russkiy kameshkir
# Processing Record 41 of Set 8 | bozeman
# Processing Record 42 of Set 8 | independencia
# Processing Record 43 of Set 8 | vila franca do campo
# Processing Record 44 of Set 8 | nantucket
# Processing Record 45 of Set 8 | jaciara
# Processing Record 46 of Set 8 | ashti
# Processing Record 47 of Set 8 | mar del plata
# Processing Record 48 of Set 8 | zhezkazgan
# Processing Record 49 of Set 8 | puerto del rosario
# Processing Record 50 of Set 8 | lebu
# Processing Record 1 of Set 9 | atar
# Processing Record 2 of Set 9 | sayyan
# Processing Record 3 of Set 9 | tokur
# Processing Record 4 of Set 9 | dunedin
# Processing Record 5 of Set 9 | sao jose da coroa grande
# Processing Record 6 of Set 9 | asau
# Processing Record 7 of Set 9 | faanui
# Processing Record 8 of Set 9 | manggar
# Processing Record 9 of Set 9 | kruisfontein
# Processing Record 10 of Set 9 | holme
# Processing Record 11 of Set 9 | abyek
# Processing Record 12 of Set 9 | whitehorse
# Processing Record 13 of Set 9 | port augusta
# Processing Record 14 of Set 9 | liverpool
# Processing Record 15 of Set 9 | emba
# Processing Record 16 of Set 9 | sibolga
# Processing Record 17 of Set 9 | vanimo
# Processing Record 18 of Set 9 | kalmunai
# Processing Record 19 of Set 9 | lannion
# Processing Record 20 of Set 9 | aberdeen
# Processing Record 21 of Set 9 | acapulco
# Processing Record 22 of Set 9 | tymovskoye
# Processing Record 23 of Set 9 | obihiro
# Processing Record 24 of Set 9 | carbonia
# Processing Record 25 of Set 9 | nortelandia
# Processing Record 26 of Set 9 | benicarlo
# Processing Record 27 of Set 9 | chilca
# Processing Record 28 of Set 9 | college
# Processing Record 29 of Set 9 | puerto baquerizo moreno
# Processing Record 30 of Set 9 | inirida
# Processing Record 31 of Set 9 | valleyview
# Processing Record 32 of Set 9 | porto novo
# Processing Record 33 of Set 9 | morgaushi
# Processing Record 34 of Set 9 | tautira
# Processing Record 35 of Set 9 | saskylakh
# Processing Record 36 of Set 9 | dan khun thot
# Processing Record 37 of Set 9 | zachary
# Processing Record 38 of Set 9 | altay
# Processing Record 39 of Set 9 | ancud
# Processing Record 40 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 9 | slave lake
# Processing Record 42 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 | djambala
# Processing Record 44 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 45 of Set 9 | kushmurun
# Processing Record 46 of Set 9 | isilkul
# Processing Record 47 of Set 9 | ayagoz
# Processing Record 48 of Set 9 | tanshui
# City not found. Skipping...
# Processing Record 49 of Set 9 | mangrol
# Processing Record 50 of Set 9 | tabukiniberu
# City not found. Skipping...
# Processing Record 1 of Set 10 | vardo
# Processing Record 2 of Set 10 | kodinsk
# Processing Record 3 of Set 10 | kamsack
# Processing Record 4 of Set 10 | muros
# Processing Record 5 of Set 10 | san carlos de bariloche
# Processing Record 6 of Set 10 | aracataca
# Processing Record 7 of Set 10 | matay
# Processing Record 8 of Set 10 | sikasso
# Processing Record 9 of Set 10 | flin flon
# Processing Record 10 of Set 10 | batagay
# Processing Record 11 of Set 10 | celano
# Processing Record 12 of Set 10 | pouembout
# Processing Record 13 of Set 10 | leon
# Processing Record 14 of Set 10 | aranos
# Processing Record 15 of Set 10 | san miguelito
# Processing Record 16 of Set 10 | yenotayevka
# Processing Record 17 of Set 10 | woodward
# Processing Record 18 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 10 | ilheus
# Processing Record 20 of Set 10 | mancio lima
# Processing Record 21 of Set 10 | dzhebariki-khaya
# Processing Record 22 of Set 10 | manta
# Processing Record 23 of Set 10 | villacarrillo
# Processing Record 24 of Set 10 | shimoda
# Processing Record 25 of Set 10 | nampula
# Processing Record 26 of Set 10 | christchurch
# Processing Record 27 of Set 10 | saint-michel-des-saints
# Processing Record 28 of Set 10 | ende
# Processing Record 29 of Set 10 | marawi
# Processing Record 30 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 31 of Set 10 | catia la mar
# Processing Record 32 of Set 10 | naryan-mar
# Processing Record 33 of Set 10 | roma
# Processing Record 34 of Set 10 | uglegorsk
# Processing Record 35 of Set 10 | brewster
# Processing Record 36 of Set 10 | shieli
# Processing Record 37 of Set 10 | ramhormoz
# Processing Record 38 of Set 10 | tutoia
# Processing Record 39 of Set 10 | rondonopolis
# Processing Record 40 of Set 10 | labis
# Processing Record 41 of Set 10 | cartagena del chaira
# Processing Record 42 of Set 10 | linhares
# Processing Record 43 of Set 10 | faya
# Processing Record 44 of Set 10 | zhuanghe
# Processing Record 45 of Set 10 | pathein
# Processing Record 46 of Set 10 | jacareacanga
# Processing Record 47 of Set 10 | clearwater
# Processing Record 48 of Set 10 | zhanaozen
# Processing Record 49 of Set 10 | mogadishu
# Processing Record 50 of Set 10 | kahului
# Processing Record 1 of Set 11 | kampot
# Processing Record 2 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 11 | avera
# Processing Record 4 of Set 11 | poum
# Processing Record 5 of Set 11 | goderich
# Processing Record 6 of Set 11 | nizwa
# Processing Record 7 of Set 11 | tres arroyos
# Processing Record 8 of Set 11 | lichuan
# Processing Record 9 of Set 11 | nouadhibou
# Processing Record 10 of Set 11 | kapitanivka
# Processing Record 11 of Set 11 | korgen
# Processing Record 12 of Set 11 | veraval
# Processing Record 13 of Set 11 | astana
# Processing Record 14 of Set 11 | burnie
# Processing Record 15 of Set 11 | beberibe
# Processing Record 16 of Set 11 | sisophon
# Processing Record 17 of Set 11 | wajir
# Processing Record 18 of Set 11 | camacha
# Processing Record 19 of Set 11 | lichinga
# Processing Record 20 of Set 11 | agadir
# Processing Record 21 of Set 11 | tasiilaq
# Processing Record 22 of Set 11 | kamenka
# Processing Record 23 of Set 11 | porto san giorgio
# Processing Record 24 of Set 11 | ixtapa
# Processing Record 25 of Set 11 | alofi
# Processing Record 26 of Set 11 | hvide sande
# Processing Record 27 of Set 11 | saint george
# Processing Record 28 of Set 11 | alexandria
# Processing Record 29 of Set 11 | igarka
# Processing Record 30 of Set 11 | aktash
# Processing Record 31 of Set 11 | fareham
# Processing Record 32 of Set 11 | kommunisticheskiy
# Processing Record 33 of Set 11 | san jeronimo
# Processing Record 34 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 11 | pontianak
# Processing Record 36 of Set 11 | lumphat
# Processing Record 37 of Set 11 | kattivakkam
# Processing Record 38 of Set 11 | katobu
# Processing Record 39 of Set 11 | ilinskoye-khovanskoye
# Processing Record 40 of Set 11 | san jose
# Processing Record 41 of Set 11 | parfenyevo
# Processing Record 42 of Set 11 | ballarat
# Processing Record 43 of Set 11 | ambilobe
# Processing Record 44 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 11 | pembroke
# Processing Record 46 of Set 11 | kapustin yar-1
# City not found. Skipping...
# Processing Record 47 of Set 11 | lukuledi
# Processing Record 48 of Set 11 | maragogi
# Processing Record 49 of Set 11 | romitan
# Processing Record 50 of Set 11 | maine-soroa
# Processing Record 1 of Set 12 | denia
# Processing Record 2 of Set 12 | noumea
# Processing Record 3 of Set 12 | ndele
# Processing Record 4 of Set 12 | bilibino
# Processing Record 5 of Set 12 | asyut
# Processing Record 6 of Set 12 | santarem
# Processing Record 7 of Set 12 | khovu-aksy
# Processing Record 8 of Set 12 | parczew
# Processing Record 9 of Set 12 | dicabisagan
# Processing Record 10 of Set 12 | atambua
# Processing Record 11 of Set 12 | pawayan
# Processing Record 12 of Set 12 | balkhash
# Processing Record 13 of Set 12 | kesennuma
# City not found. Skipping...
# Processing Record 14 of Set 12 | wasilla
# Processing Record 15 of Set 12 | chapleau
# Processing Record 16 of Set 12 | state college
# Processing Record 17 of Set 12 | smithers
# Processing Record 18 of Set 12 | xiamen
# Processing Record 19 of Set 12 | dabra
# Processing Record 20 of Set 12 | karpogory
# Processing Record 21 of Set 12 | mount isa
# Processing Record 22 of Set 12 | mount pleasant
# Processing Record 23 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 24 of Set 12 | sur
# Processing Record 25 of Set 12 | ekibastuz
# Processing Record 26 of Set 12 | munster
# Processing Record 27 of Set 12 | trinidad
# Processing Record 28 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 29 of Set 12 | paamiut
# Processing Record 30 of Set 12 | tabas
# Processing Record 31 of Set 12 | otane
# Processing Record 32 of Set 12 | catamarca
# Processing Record 33 of Set 12 | takoradi
# Processing Record 34 of Set 12 | kamaishi
# Processing Record 35 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 36 of Set 12 | khasan
# Processing Record 37 of Set 12 | son tay
# Processing Record 38 of Set 12 | srednekolymsk
# Processing Record 39 of Set 12 | bonga
# Processing Record 40 of Set 12 | maniitsoq
# Processing Record 41 of Set 12 | dingli
# Processing Record 42 of Set 12 | puksoozero
# Processing Record 43 of Set 12 | luderitz
# Processing Record 44 of Set 12 | srivardhan
# Processing Record 45 of Set 12 | fort nelson
# Processing Record 46 of Set 12 | marrakesh
# Processing Record 47 of Set 12 | yelnya
# Processing Record 48 of Set 12 | hobyo
# Processing Record 49 of Set 12 | itacarambi
# Processing Record 50 of Set 12 | gafanha da encarnacao
# Processing Record 1 of Set 13 | bhan
# Processing Record 2 of Set 13 | takapau
# Processing Record 3 of Set 13 | koboldo
# City not found. Skipping...
# Processing Record 4 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 13 | khorramshahr
# Processing Record 6 of Set 13 | shakiso
# Processing Record 7 of Set 13 | balakirevo
# Processing Record 8 of Set 13 | dakar
# Processing Record 9 of Set 13 | oranjemund
# Processing Record 10 of Set 13 | three hills
# Processing Record 11 of Set 13 | shelburne
# Processing Record 12 of Set 13 | polyarnyy
# Processing Record 13 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 13 | sohag
# Processing Record 15 of Set 13 | aklavik
# Processing Record 16 of Set 13 | faratsiho
# Processing Record 17 of Set 13 | caohe
# Processing Record 18 of Set 13 | coronel mariduena
# City not found. Skipping...
# Processing Record 19 of Set 13 | arman
# Processing Record 20 of Set 13 | lake charles
# Processing Record 21 of Set 13 | bonavista
# Processing Record 22 of Set 13 | vredendal
# Processing Record 23 of Set 13 | northam
# Processing Record 24 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 13 | kuito
# Processing Record 26 of Set 13 | lagos
# Processing Record 27 of Set 13 | kirksville
# Processing Record 28 of Set 13 | moree
# Processing Record 29 of Set 13 | tambacounda
# Processing Record 30 of Set 13 | bubaque
# Processing Record 31 of Set 13 | cooma
# Processing Record 32 of Set 13 | mayo
# Processing Record 33 of Set 13 | vestmanna
# Processing Record 34 of Set 13 | lieto
# Processing Record 35 of Set 13 | yar-sale
# Processing Record 36 of Set 13 | partsa
# Processing Record 37 of Set 13 | ossora
# Processing Record 38 of Set 13 | savona
# Processing Record 39 of Set 13 | hopfgarten
# Processing Record 40 of Set 13 | potiskum
# Processing Record 41 of Set 13 | nabul
# City not found. Skipping...
# Processing Record 42 of Set 13 | vila velha
# Processing Record 43 of Set 13 | greifswald
# Processing Record 44 of Set 13 | ampanihy
# Processing Record 45 of Set 13 | hurghada
# Processing Record 46 of Set 13 | auki
# Processing Record 47 of Set 13 | kerman
# Processing Record 48 of Set 13 | gold coast
# Processing Record 49 of Set 13 | constantine
# Processing Record 50 of Set 13 | coihueco
# Processing Record 1 of Set 14 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 2 of Set 14 | sexsmith
# Processing Record 3 of Set 14 | tandalti
# Processing Record 4 of Set 14 | santa cruz de la palma
# Processing Record 5 of Set 14 | troitskoye
# Processing Record 6 of Set 14 | tevriz
# Processing Record 7 of Set 14 | makakilo city
# Processing Record 8 of Set 14 | klyuchevskiy
# Processing Record 9 of Set 14 | guarapari
# Processing Record 10 of Set 14 | naze
# Processing Record 11 of Set 14 | obigarm
# Processing Record 12 of Set 14 | nisia floresta
# Processing Record 13 of Set 14 | almaty
# Processing Record 14 of Set 14 | point fortin
# Processing Record 15 of Set 14 | puerto gaitan
# Processing Record 16 of Set 14 | lagoa
# Processing Record 17 of Set 14 | gazojak
# Processing Record 18 of Set 14 | jalu
# Processing Record 19 of Set 14 | naples
# Processing Record 20 of Set 14 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 21 of Set 14 | alekseyevsk
# Processing Record 22 of Set 14 | plotnikovo
# Processing Record 23 of Set 14 | port hawkesbury
# Processing Record 24 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 14 | looc
# Processing Record 26 of Set 14 | lukulu
# Processing Record 27 of Set 14 | aksu
# Processing Record 28 of Set 14 | tommot
# Processing Record 29 of Set 14 | thurso
# Processing Record 30 of Set 14 | haines junction
# Processing Record 31 of Set 14 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 32 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 33 of Set 14 | filotion
# Processing Record 34 of Set 14 | verkhoyansk
# Processing Record 35 of Set 14 | villa guerrero
# Processing Record 36 of Set 14 | namibe
# Processing Record 37 of Set 14 | muravlenko
# Processing Record 38 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 14 | chifeng
# Processing Record 40 of Set 14 | arak
# Processing Record 41 of Set 14 | uzunovo
# Processing Record 42 of Set 14 | north fort myers
# Processing Record 43 of Set 14 | polson
# Processing Record 44 of Set 14 | alice springs
# Processing Record 45 of Set 14 | lima
# Processing Record 46 of Set 14 | cove
# Processing Record 47 of Set 14 | soma
# Processing Record 48 of Set 14 | xining
# Processing Record 49 of Set 14 | saint-pierre
# Processing Record 50 of Set 14 | aripuana
# Processing Record 1 of Set 15 | rodrigues alves
# Processing Record 2 of Set 15 | guerande
# Processing Record 3 of Set 15 | hailar
# Processing Record 4 of Set 15 | north bend
# Processing Record 5 of Set 15 | lensk
# Processing Record 6 of Set 15 | kishtwar
# Processing Record 7 of Set 15 | hualmay
# Processing Record 8 of Set 15 | puerto escondido
# Processing Record 9 of Set 15 | yerbogachen
# Processing Record 10 of Set 15 | lae
# Processing Record 11 of Set 15 | vao
# Processing Record 12 of Set 15 | kungurtug
# Processing Record 13 of Set 15 | bulaevo
# Processing Record 14 of Set 15 | tulle
# Processing Record 15 of Set 15 | mazyr
# Processing Record 16 of Set 15 | birao
# Processing Record 17 of Set 15 | belyy yar
# Processing Record 18 of Set 15 | podyuga
# Processing Record 19 of Set 15 | lushoto
# Processing Record 20 of Set 15 | inuvik
# Processing Record 21 of Set 15 | caimitillo
# Processing Record 22 of Set 15 | praya
# Processing Record 23 of Set 15 | mareeba
# Processing Record 24 of Set 15 | mnogovershinnyy
# Processing Record 25 of Set 15 | douentza
# Processing Record 26 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 27 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 15 | ostrovnoy
# Processing Record 29 of Set 15 | mbanza-ngungu
# Processing Record 30 of Set 15 | road town
# Processing Record 31 of Set 15 | zhangye
# Processing Record 32 of Set 15 | broome
# Processing Record 33 of Set 15 | sulangan
# Processing Record 34 of Set 15 | rawson
# Processing Record 35 of Set 15 | kibaya
# Processing Record 36 of Set 15 | sauda
# Processing Record 37 of Set 15 | saint marys
# Processing Record 38 of Set 15 | sal rei
# Processing Record 39 of Set 15 | cape canaveral
# Processing Record 40 of Set 15 | ban nahin
# Processing Record 41 of Set 15 | wajima
# Processing Record 42 of Set 15 | kasama
# Processing Record 43 of Set 15 | treinta y tres
# Processing Record 44 of Set 15 | lishui
# Processing Record 45 of Set 15 | ratangarh
# Processing Record 46 of Set 15 | mtambile
# Processing Record 47 of Set 15 | gat
# Processing Record 48 of Set 15 | sakakah
# Processing Record 49 of Set 15 | pedraza
# Processing Record 50 of Set 15 | neyveli
# Processing Record 1 of Set 16 | cabra
# Processing Record 2 of Set 16 | la rioja
# Processing Record 3 of Set 16 | lukovetskiy
# Processing Record 4 of Set 16 | hastings
# Processing Record 5 of Set 16 | aix-en-provence
# Processing Record 6 of Set 16 | portland
# Processing Record 7 of Set 16 | piryion
# City not found. Skipping...
# Processing Record 8 of Set 16 | fez
# Processing Record 9 of Set 16 | jiazi
# Processing Record 10 of Set 16 | platanos
# Processing Record 11 of Set 16 | brownsville
# Processing Record 12 of Set 16 | quesnel
# Processing Record 13 of Set 16 | azimur
# City not found. Skipping...
# Processing Record 14 of Set 16 | bairiki
# Processing Record 15 of Set 16 | tual
# Processing Record 16 of Set 16 | zhoucheng
# Processing Record 17 of Set 16 | gevrai
# Processing Record 18 of Set 16 | huarmey
# Processing Record 19 of Set 16 | las vegas
# Processing Record 20 of Set 16 | zatoka
# Processing Record 21 of Set 16 | novobirilyussy
# Processing Record 22 of Set 16 | nanakuli
# Processing Record 23 of Set 16 | carutapera
# Processing Record 24 of Set 16 | tabatinga
# Processing Record 25 of Set 16 | yumen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hermanus -34.4187   19.2345     57.99        79           5
# 1  Batagay-Alyta  67.8006  130.4114      3.78        89         100
# 2        Ahipara -35.1667  173.1667     66.16        90         100
# 3  Marsh Harbour  26.5412  -77.0636     76.26        71           0
# 4    Port Alfred -33.5906   26.8910     63.36        74          49
# 5  Prince Rupert  54.3161 -130.3201     44.60       100          90
# 6   Punta Arenas -53.1500  -70.9167     51.80        62          20
# 7        Cayenne   4.9333  -52.3333     80.01        83          75
# 8           Lasa  46.6166   10.7002     50.00        75           0
# 9   Port Lincoln -34.7333  135.8667     62.08        68          21
#
#    Wind Speed Country                 Date       Description
# 0        1.01      ZA  2021-03-27 22:54:11         clear sky
# 1        3.15      RU  2021-03-27 22:55:42   overcast clouds
# 2       12.03      NZ  2021-03-27 22:55:43   overcast clouds
# 3       14.09      BS  2021-03-27 22:55:43         clear sky
# 4        8.86      ZA  2021-03-27 22:54:11  scattered clouds
# 5       16.11      CA  2021-03-27 22:55:44     moderate rain
# 6       31.07      CL  2021-03-27 22:52:20        light rain
# 7        9.22      GF  2021-03-27 22:55:44     broken clouds
# 8        5.75      IT  2021-03-27 22:55:45         clear sky
# 9        3.11      AU  2021-03-27 22:55:45        few clouds

# %%
city_data_new_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']

# %%
city_data_df = city_data_df[city_data_new_order]
city_data_df.head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0       Hermanus      ZA  2021-03-27 22:54:11 -34.4187   19.2345     57.99
# 1  Batagay-Alyta      RU  2021-03-27 22:55:42  67.8006  130.4114      3.78
# 2        Ahipara      NZ  2021-03-27 22:55:43 -35.1667  173.1667     66.16
# 3  Marsh Harbour      BS  2021-03-27 22:55:43  26.5412  -77.0636     76.26
# 4    Port Alfred      ZA  2021-03-27 22:54:11 -33.5906   26.8910     63.36
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        79           5        1.01         clear sky
# 1        89         100        3.15   overcast clouds
# 2        90         100       12.03   overcast clouds
# 3        71           0       14.09         clear sky
# 4        74          49        8.86  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
